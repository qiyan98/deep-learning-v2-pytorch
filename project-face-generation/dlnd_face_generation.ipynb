# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/qiyan/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
from torch.utils.data import DataLoader

def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    celeba_trans = transforms.Compose([
                    transforms.Resize(image_size),
                    transforms.ToTensor()])
    celeba_dataset = datasets.ImageFolder(root=data_dir,transform=celeba_trans)
    celeba_loader = DataLoader(celeba_dataset,batch_size=batch_size,shuffle=True)

    return celeba_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = (32,32)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    if x.min() < 0 or x.max() > 1:
        raise Exception('X should be in [0,1] !')
    min_val, max_val = feature_range
    x = min_val + (max_val - min_val)*x
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9922)
# Max:  tensor(0.7333)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class ResBlock(nn.Module):
    def __init__(self, in_channel, out_channel, stride = 1):
        super(ResBlock, self).__init__()
        
        self.res_conv1 = nn.Conv2d(in_channel, out_channel, 5, stride, 2)
        self.res_bn1 = nn.BatchNorm2d(out_channel)
        self.res_conv2 = nn.Conv2d(out_channel, out_channel, 5, 1, 2)
        self.res_bn2 = nn.BatchNorm2d(out_channel)
        self.res_conv3 = nn.Conv2d(out_channel, out_channel, 5, 1, 2)
        self.res_bn3 = nn.BatchNorm2d(out_channel)
        
        self.res_skip = nn.Conv2d(in_channel,out_channel,5,stride,2)
        self.res_skip_bn = nn.BatchNorm2d(out_channel)
        
        self.res_out_bn = nn.BatchNorm2d(out_channel)
        
    def forward(self,x):
        res = x
        x = F.relu(self.res_bn1(self.res_conv1(x)))
        x = F.relu(self.res_bn2(self.res_conv2(x)))
        x = F.relu(self.res_bn3(self.res_conv3(x)))
        
        x += F.relu(self.res_skip_bn(self.res_skip(res)))
        x = F.relu(self.res_out_bn(x))
        
        return x
        
class Discriminator(nn.Module):

    def __init__(self, conv_dim, block = ResBlock):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        self.conv1 = nn.Conv2d(3,self.conv_dim,5,2,2)
        self.bn1 = nn.BatchNorm2d(self.conv_dim)
        
        self.layer1 = self._make_layer(block, self.conv_dim, 128, 1, stride=4)
        
        self.fc = nn.Linear(128*4*4,1)
        
    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        
        # implement resnet-style block
        x = F.relu(self.bn1(self.conv1(x))) # conv_dimx16x16, layer 1
        x = self.layer1(x) # 128x4x4, layer 2-4
        
        x = x.view(-1,128*4*4)
        x = self.fc(x) # use BCEWithLogitsLoss to avoid numerical issue
        
        return x
    
    def _make_layer(self, block, in_channel, out_channel, num_blocks, stride):
        layers = []
        strides = np.ones(num_blocks,'int')*stride
        for s in strides:
            layers.append(block(in_channel, out_channel, s))
        return nn.Sequential(*layers)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
class ResBlockTrans(nn.Module):
    
    def __init__(self, in_channel, out_channel, stride=2):
        super(ResBlockTrans, self).__init__()
        
        if stride == 2:
            self.res_conv1 = nn.ConvTranspose2d(in_channel, out_channel, 4, stride, 1)
            self.res_conv2 = nn.ConvTranspose2d(out_channel, out_channel, 4, stride, 1)
            self.res_conv3 = nn.ConvTranspose2d(out_channel, out_channel, 4, stride, 1)
            self.res_skip = nn.ConvTranspose2d(in_channel, out_channel, 8, stride**3, 0)
        elif stride == 1:
            self.res_conv1 = nn.ConvTranspose2d(in_channel, out_channel, 5, stride, 2)
            self.res_conv2 = nn.ConvTranspose2d(out_channel, out_channel, 5, stride, 2)
            self.res_conv3 = nn.ConvTranspose2d(out_channel, out_channel, 5, stride, 2)
            self.res_skip = nn.ConvTranspose2d(in_channel, out_channel, 5, stride,2)
        
        self.res_bn1 = nn.BatchNorm2d(out_channel)
        self.res_bn2 = nn.BatchNorm2d(out_channel)
        self.res_bn3 = nn.BatchNorm2d(out_channel)
        
        self.res_skip_bn = nn.BatchNorm2d(out_channel)
        
        self.res_out_bn = nn.BatchNorm2d(out_channel)
        
    def forward(self,x):
        res = x
        x = F.relu(self.res_bn1(self.res_conv1(x)))
        x = F.relu(self.res_bn2(self.res_conv2(x)))
        x = F.relu(self.res_bn3(self.res_conv3(x)))
        x += F.relu(self.res_skip_bn(self.res_skip(res)))
        x = F.relu(self.res_out_bn(x))
        
        return x
        
        
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim, block = ResBlockTrans):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.z_size = z_size
        self.conv_dim = conv_dim
        
        self.fc = nn.Linear(z_size, 4*4*4*self.conv_dim)
        self.fc_bn = nn.BatchNorm1d(4*4*4*self.conv_dim)
        
        self.layer1 = self._make_layer(block, 4*self.conv_dim, 4*self.conv_dim, 1, stride=2) # 32x32
        self.layer2 = self._make_layer(block, 4*self.conv_dim, 4*self.conv_dim, 1, stride=1) # 32x32
        
        self.convT1 = nn.ConvTranspose2d(4*self.conv_dim,3,5,1,2)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        batch_size = x.shape[0]
        x = F.relu(self.fc_bn(self.fc(x))) # layer 1
        x = x.view(-1,4*self.conv_dim,4,4)
        x = self.layer1(x) # layer 2-4
        x = self.layer2(x) # layer 5-7
        x = self.convT1(x)
        x = torch.tanh(x)
        
        return x

    def _make_layer(self,block, in_channel, out_channel, num_blocks, stride):
        strides_list = np.ones(num_blocks,'int')*stride
        layer = []
        for s in strides_list:
            layer.append(block(in_channel, out_channel, s))
        return nn.Sequential(*layer)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
from torch.nn import init

def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    # TODO: Apply initial weights to convolutional and linear layers
    if hasattr(m,'weight'):
        if 'Conv' in classname or 'Linear' in classname:
            init.normal_(m.weight.data, 0.0, 0.02)
            if hasattr(m,'bias') and m.bias is not None:
                init.constant_(m.bias.data, 0.0)
        elif 'BatchNorm' in classname:
            init.normal_(m.weight.data, 1.0, 0.02)
            init.constant_(m.bias.data, 0.0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 64

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Conv2d(3, 32, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): ResBlock(
#       (res_conv1): Conv2d(32, 128, kernel_size=(5, 5), stride=(4, 4), padding=(2, 2))
#       (res_bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (res_conv2): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (res_bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (res_conv3): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (res_bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (res_skip): Conv2d(32, 128, kernel_size=(5, 5), stride=(4, 4), padding=(2, 2))
#       (res_skip_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (res_out_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=64, out_features=2048, bias=True)
#   (fc_bn): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): ResBlockTrans(
#       (res_conv1): ConvTranspose2d(128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (res_conv2): ConvTranspose2d(128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (res_conv3): ConvTranspose2d(128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (res_skip): ConvTranspose2d(128, 128, kernel_size=(8, 8), stride=(8, 8))
#       (res_bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (res_bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (res_bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (res_skip_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (res_out_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): ResBlockTrans(
#       (res_conv1): ConvTranspose2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (res_conv2): ConvTranspose2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (res_conv3): ConvTranspose2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (res_skip): ConvTranspose2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (res_bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (res_bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (res_bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (res_skip_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (res_out_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (convT1): ConvTranspose2d(128, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    target = torch.ones([batch_size,1]) - 0.05*torch.ones([batch_size,1]) # add noise to soften label
    if train_on_gpu:
        target = target.cuda()
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out,target)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    target = torch.zeros([batch_size,1]) + 0.05*torch.ones([batch_size,1]) # add noise to soften label
    if train_on_gpu:
        target = target.cuda()
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out,target)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# Create optimizers for the discriminator D and generator G
adam_betas = (0.3,0.999)
d_optimizer = optim.Adam(D.parameters(),lr=1e-4, betas=adam_betas)
g_optimizer = optim.Adam(G.parameters(),lr=1e-4, betas=adam_betas)

d_lrs = optim.lr_scheduler.StepLR(d_optimizer,step_size=10,gamma=0.5)
g_lrs = optim.lr_scheduler.StepLR(g_optimizer,step_size=10,gamma=0.5)

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
import time
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):
        time_start = time.time()
        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            D.zero_grad()
            
            # Real images training loss
            if train_on_gpu:
                real_images = real_images.cuda().float()
            d_out_real = D(real_images)
            
            # Fake images training loss
            z_vec = torch.FloatTensor(batch_size,z_size).uniform_(-1,1)
            if train_on_gpu:
                z_vec = z_vec.cuda()
            g_out_fake = G(z_vec)
            d_out_fake = D(g_out_fake)
            
            # Total loss and backprop.
            d_loss = real_loss(d_out_real) + fake_loss(d_out_fake)
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            G.zero_grad()
            
            # Create fake images and obtain its loss
            z_vec = torch.FloatTensor(batch_size,z_size).uniform_(-1,1)
            if train_on_gpu:
                z_vec = z_vec.cuda()
            g_out_fake = G(z_vec)
            d_out_fake = D(g_out_fake)
            g_loss = real_loss(d_out_fake) # min. real_loss to make fake images look more real to the discriminator
            
            g_loss.backward()
            g_optimizer.step()
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            elapsed = time.time() - time_start
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f} | speed: {:4.3f} s/batch'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item(), elapsed/(batch_i+1)))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode
        
        d_lrs.step()
        g_lrs.step()
        
        time_epoch = time.time() - time_start
        print("Epoch {:d}/{:d} time: {:.2f}s".format(epoch+1, n_epochs, time_epoch))

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 30


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   30] | d_loss: 1.5271 | g_loss: 0.9118 | speed: 0.391 s/batch
# Epoch [    1/   30] | d_loss: 0.6214 | g_loss: 3.4878 | speed: 0.213 s/batch
# Epoch [    1/   30] | d_loss: 0.5772 | g_loss: 3.3285 | speed: 0.213 s/batch
# Epoch [    1/   30] | d_loss: 0.5658 | g_loss: 2.2777 | speed: 0.218 s/batch
# Epoch [    1/   30] | d_loss: 1.5094 | g_loss: 2.8966 | speed: 0.219 s/batch
# Epoch [    1/   30] | d_loss: 1.0271 | g_loss: 2.9080 | speed: 0.220 s/batch
# Epoch [    1/   30] | d_loss: 0.7190 | g_loss: 1.8010 | speed: 0.223 s/batch
# Epoch [    1/   30] | d_loss: 0.6120 | g_loss: 1.8964 | speed: 0.223 s/batch
# Epoch [    1/   30] | d_loss: 0.7732 | g_loss: 1.8108 | speed: 0.223 s/batch
# Epoch [    1/   30] | d_loss: 0.8723 | g_loss: 2.0392 | speed: 0.224 s/batch
# Epoch [    1/   30] | d_loss: 0.6946 | g_loss: 2.2499 | speed: 0.230 s/batch
# Epoch [    1/   30] | d_loss: 0.7747 | g_loss: 1.6040 | speed: 0.241 s/batch
# Epoch [    1/   30] | d_loss: 0.7519 | g_loss: 1.5334 | speed: 0.250 s/batch
# Epoch [    1/   30] | d_loss: 0.6514 | g_loss: 1.8098 | speed: 0.258 s/batch
# Epoch [    1/   30] | d_loss: 0.9052 | g_loss: 1.1122 | speed: 0.265 s/batch
# Epoch 1/30 time: 186.10s
# Epoch [    2/   30] | d_loss: 0.9330 | g_loss: 1.6153 | speed: 0.327 s/batch
# Epoch [    2/   30] | d_loss: 0.8009 | g_loss: 2.1449 | speed: 0.352 s/batch
# Epoch [    2/   30] | d_loss: 0.7004 | g_loss: 1.6789 | speed: 0.353 s/batch
# Epoch [    2/   30] | d_loss: 0.8644 | g_loss: 1.3058 | speed: 0.353 s/batch
# Epoch [    2/   30] | d_loss: 0.9650 | g_loss: 1.2268 | speed: 0.352 s/batch
# Epoch [    2/   30] | d_loss: 0.6946 | g_loss: 1.5549 | speed: 0.352 s/batch
# Epoch [    2/   30] | d_loss: 1.0848 | g_loss: 2.6284 | speed: 0.352 s/batch
# Epoch [    2/   30] | d_loss: 0.9383 | g_loss: 2.0843 | speed: 0.352 s/batch
# Epoch [    2/   30] | d_loss: 0.9584 | g_loss: 1.6143 | speed: 0.352 s/batch
# Epoch [    2/   30] | d_loss: 0.7854 | g_loss: 2.3607 | speed: 0.351 s/batch
# Epoch [    2/   30] | d_loss: 0.7763 | g_loss: 1.7461 | speed: 0.351 s/batch
# Epoch [    2/   30] | d_loss: 0.9926 | g_loss: 2.2853 | speed: 0.351 s/batch
# Epoch [    2/   30] | d_loss: 0.7599 | g_loss: 2.1127 | speed: 0.351 s/batch
# Epoch [    2/   30] | d_loss: 1.2078 | g_loss: 1.0878 | speed: 0.351 s/batch
# Epoch [    2/   30] | d_loss: 1.3035 | g_loss: 1.6545 | speed: 0.351 s/batch
# Epoch 2/30 time: 246.81s
# Epoch [    3/   30] | d_loss: 0.9026 | g_loss: 1.5923 | speed: 0.335 s/batch
# Epoch [    3/   30] | d_loss: 1.2948 | g_loss: 1.5159 | speed: 0.350 s/batch
# Epoch [    3/   30] | d_loss: 0.7543 | g_loss: 1.7273 | speed: 0.303 s/batch
# Epoch [    3/   30] | d_loss: 0.8030 | g_loss: 1.6396 | speed: 0.277 s/batch
# Epoch [    3/   30] | d_loss: 1.4520 | g_loss: 0.9048 | speed: 0.263 s/batch
# Epoch [    3/   30] | d_loss: 0.7514 | g_loss: 1.9248 | speed: 0.255 s/batch
# Epoch [    3/   30] | d_loss: 0.9835 | g_loss: 1.4402 | speed: 0.250 s/batch
# Epoch [    3/   30] | d_loss: 1.2540 | g_loss: 0.9375 | speed: 0.246 s/batch
# Epoch [    3/   30] | d_loss: 0.9369 | g_loss: 1.7029 | speed: 0.243 s/batch
# Epoch [    3/   30] | d_loss: 0.9275 | g_loss: 1.9356 | speed: 0.241 s/batch
# Epoch [    3/   30] | d_loss: 1.2384 | g_loss: 0.9299 | speed: 0.239 s/batch
# Epoch [    3/   30] | d_loss: 0.9873 | g_loss: 1.5714 | speed: 0.238 s/batch
# Epoch [    3/   30] | d_loss: 1.0803 | g_loss: 1.3395 | speed: 0.237 s/batch
# Epoch [    3/   30] | d_loss: 0.7202 | g_loss: 1.6780 | speed: 0.236 s/batch
# Epoch [    3/   30] | d_loss: 0.8387 | g_loss: 2.0690 | speed: 0.235 s/batch
# Epoch 3/30 time: 164.92s
# Epoch [    4/   30] | d_loss: 0.9069 | g_loss: 2.0744 | speed: 0.215 s/batch
# Epoch [    4/   30] | d_loss: 1.0121 | g_loss: 1.8939 | speed: 0.223 s/batch
# Epoch [    4/   30] | d_loss: 0.8547 | g_loss: 2.7181 | speed: 0.223 s/batch
# Epoch [    4/   30] | d_loss: 0.8369 | g_loss: 2.4015 | speed: 0.223 s/batch
# Epoch [    4/   30] | d_loss: 0.7413 | g_loss: 2.0127 | speed: 0.223 s/batch
# Epoch [    4/   30] | d_loss: 0.7582 | g_loss: 1.7711 | speed: 0.223 s/batch
# Epoch [    4/   30] | d_loss: 0.9198 | g_loss: 1.8041 | speed: 0.223 s/batch
# Epoch [    4/   30] | d_loss: 0.8489 | g_loss: 1.5986 | speed: 0.223 s/batch
# Epoch [    4/   30] | d_loss: 1.0798 | g_loss: 1.2848 | speed: 0.223 s/batch
# Epoch [    4/   30] | d_loss: 1.1147 | g_loss: 1.6948 | speed: 0.223 s/batch
# Epoch [    4/   30] | d_loss: 0.7352 | g_loss: 2.2490 | speed: 0.223 s/batch
# Epoch [    4/   30] | d_loss: 0.9114 | g_loss: 1.4737 | speed: 0.223 s/batch
# Epoch [    4/   30] | d_loss: 0.8692 | g_loss: 3.9466 | speed: 0.223 s/batch
# Epoch [    4/   30] | d_loss: 0.8543 | g_loss: 2.0486 | speed: 0.223 s/batch
# Epoch [    4/   30] | d_loss: 0.7932 | g_loss: 1.5855 | speed: 0.223 s/batch
# Epoch 4/30 time: 156.55s
# Epoch [    5/   30] | d_loss: 0.7625 | g_loss: 1.5458 | speed: 0.212 s/batch
# Epoch [    5/   30] | d_loss: 0.7571 | g_loss: 2.1008 | speed: 0.222 s/batch
# Epoch [    5/   30] | d_loss: 0.6937 | g_loss: 1.8477 | speed: 0.222 s/batch
# Epoch [    5/   30] | d_loss: 0.8673 | g_loss: 2.1158 | speed: 0.223 s/batch
# Epoch [    5/   30] | d_loss: 1.0907 | g_loss: 1.2943 | speed: 0.222 s/batch
# Epoch [    5/   30] | d_loss: 1.1925 | g_loss: 1.7424 | speed: 0.222 s/batch
# Epoch [    5/   30] | d_loss: 1.3269 | g_loss: 1.7536 | speed: 0.222 s/batch
# Epoch [    5/   30] | d_loss: 0.8558 | g_loss: 3.3256 | speed: 0.223 s/batch
# Epoch [    5/   30] | d_loss: 0.7383 | g_loss: 1.8786 | speed: 0.224 s/batch
# Epoch [    5/   30] | d_loss: 0.7642 | g_loss: 1.9247 | speed: 0.224 s/batch
# Epoch [    5/   30] | d_loss: 1.7624 | g_loss: 1.6207 | speed: 0.225 s/batch
# Epoch [    5/   30] | d_loss: 0.9869 | g_loss: 1.7493 | speed: 0.225 s/batch
# Epoch [    5/   30] | d_loss: 0.8546 | g_loss: 1.5931 | speed: 0.225 s/batch
# Epoch [    5/   30] | d_loss: 0.7703 | g_loss: 2.1928 | speed: 0.226 s/batch
# Epoch [    5/   30] | d_loss: 1.3751 | g_loss: 1.5365 | speed: 0.226 s/batch
# Epoch 5/30 time: 158.90s
# Epoch [    6/   30] | d_loss: 0.9962 | g_loss: 1.2820 | speed: 0.213 s/batch
# Epoch [    6/   30] | d_loss: 0.9128 | g_loss: 1.8534 | speed: 0.230 s/batch
# Epoch [    6/   30] | d_loss: 0.9800 | g_loss: 1.7717 | speed: 0.232 s/batch
# Epoch [    6/   30] | d_loss: 0.9417 | g_loss: 2.1429 | speed: 0.231 s/batch
# Epoch [    6/   30] | d_loss: 0.9986 | g_loss: 1.2971 | speed: 0.229 s/batch
# Epoch [    6/   30] | d_loss: 0.9849 | g_loss: 1.8373 | speed: 0.229 s/batch
# Epoch [    6/   30] | d_loss: 0.7911 | g_loss: 1.5320 | speed: 0.229 s/batch
# Epoch [    6/   30] | d_loss: 0.8405 | g_loss: 1.7929 | speed: 0.230 s/batch
# Epoch [    6/   30] | d_loss: 1.2721 | g_loss: 1.3323 | speed: 0.231 s/batch
# Epoch [    6/   30] | d_loss: 0.8640 | g_loss: 1.3581 | speed: 0.230 s/batch
# Epoch [    6/   30] | d_loss: 1.0475 | g_loss: 1.3885 | speed: 0.231 s/batch
# Epoch [    6/   30] | d_loss: 1.0828 | g_loss: 1.1025 | speed: 0.231 s/batch
# Epoch [    6/   30] | d_loss: 0.8245 | g_loss: 1.3267 | speed: 0.231 s/batch
# Epoch [    6/   30] | d_loss: 1.0022 | g_loss: 2.3853 | speed: 0.230 s/batch
# Epoch [    6/   30] | d_loss: 1.0082 | g_loss: 1.3307 | speed: 0.230 s/batch
# Epoch 6/30 time: 161.94s
# Epoch [    7/   30] | d_loss: 1.1253 | g_loss: 1.5525 | speed: 0.214 s/batch
# Epoch [    7/   30] | d_loss: 1.2525 | g_loss: 2.3747 | speed: 0.228 s/batch
# Epoch [    7/   30] | d_loss: 0.9297 | g_loss: 1.6208 | speed: 0.227 s/batch
# Epoch [    7/   30] | d_loss: 1.0476 | g_loss: 2.2034 | speed: 0.228 s/batch
# Epoch [    7/   30] | d_loss: 0.9131 | g_loss: 1.6391 | speed: 0.227 s/batch
# Epoch [    7/   30] | d_loss: 1.0147 | g_loss: 1.0583 | speed: 0.226 s/batch
# Epoch [    7/   30] | d_loss: 1.0050 | g_loss: 1.0261 | speed: 0.227 s/batch
# Epoch [    7/   30] | d_loss: 0.9541 | g_loss: 1.7561 | speed: 0.228 s/batch
# Epoch [    7/   30] | d_loss: 1.0959 | g_loss: 1.5850 | speed: 0.230 s/batch
# Epoch [    7/   30] | d_loss: 1.0943 | g_loss: 1.3368 | speed: 0.231 s/batch
# Epoch [    7/   30] | d_loss: 0.9744 | g_loss: 1.2148 | speed: 0.230 s/batch
# Epoch [    7/   30] | d_loss: 0.9124 | g_loss: 1.0405 | speed: 0.229 s/batch
# Epoch [    7/   30] | d_loss: 1.3427 | g_loss: 2.4878 | speed: 0.229 s/batch
# Epoch [    7/   30] | d_loss: 0.9212 | g_loss: 1.7706 | speed: 0.229 s/batch
# Epoch [    7/   30] | d_loss: 1.0162 | g_loss: 1.4412 | speed: 0.229 s/batch
# Epoch 7/30 time: 161.19s
# Epoch [    8/   30] | d_loss: 0.9463 | g_loss: 1.3462 | speed: 0.240 s/batch
# Epoch [    8/   30] | d_loss: 1.0210 | g_loss: 1.5496 | speed: 0.227 s/batch
# Epoch [    8/   30] | d_loss: 1.0239 | g_loss: 1.3591 | speed: 0.226 s/batch
# Epoch [    8/   30] | d_loss: 0.8647 | g_loss: 1.5118 | speed: 0.225 s/batch
# Epoch [    8/   30] | d_loss: 1.0708 | g_loss: 1.3731 | speed: 0.225 s/batch
# Epoch [    8/   30] | d_loss: 1.1837 | g_loss: 2.3243 | speed: 0.230 s/batch
# Epoch [    8/   30] | d_loss: 0.8818 | g_loss: 1.4088 | speed: 0.232 s/batch
# Epoch [    8/   30] | d_loss: 1.1790 | g_loss: 0.7290 | speed: 0.232 s/batch
# Epoch [    8/   30] | d_loss: 0.9003 | g_loss: 1.6597 | speed: 0.231 s/batch
# Epoch [    8/   30] | d_loss: 1.0067 | g_loss: 1.8776 | speed: 0.230 s/batch
# Epoch [    8/   30] | d_loss: 0.9383 | g_loss: 1.3490 | speed: 0.230 s/batch
# Epoch [    8/   30] | d_loss: 0.8117 | g_loss: 1.9041 | speed: 0.229 s/batch
# Epoch [    8/   30] | d_loss: 0.9282 | g_loss: 1.4739 | speed: 0.229 s/batch
# Epoch [    8/   30] | d_loss: 1.0659 | g_loss: 1.9906 | speed: 0.229 s/batch
# Epoch [    8/   30] | d_loss: 1.1849 | g_loss: 1.4641 | speed: 0.228 s/batch
# Epoch 8/30 time: 160.42s
# Epoch [    9/   30] | d_loss: 0.8838 | g_loss: 1.3797 | speed: 0.212 s/batch
# Epoch [    9/   30] | d_loss: 1.0125 | g_loss: 1.1092 | speed: 0.228 s/batch
# Epoch [    9/   30] | d_loss: 0.8929 | g_loss: 1.2629 | speed: 0.235 s/batch
# Epoch [    9/   30] | d_loss: 1.0444 | g_loss: 1.0711 | speed: 0.234 s/batch
# Epoch [    9/   30] | d_loss: 1.1017 | g_loss: 0.9807 | speed: 0.232 s/batch
# Epoch [    9/   30] | d_loss: 1.0222 | g_loss: 1.4445 | speed: 0.230 s/batch
# Epoch [    9/   30] | d_loss: 0.9518 | g_loss: 1.5277 | speed: 0.229 s/batch
# Epoch [    9/   30] | d_loss: 1.3426 | g_loss: 1.4895 | speed: 0.229 s/batch
# Epoch [    9/   30] | d_loss: 1.0058 | g_loss: 1.1841 | speed: 0.228 s/batch
# Epoch [    9/   30] | d_loss: 1.2045 | g_loss: 1.4988 | speed: 0.228 s/batch
# Epoch [    9/   30] | d_loss: 0.9823 | g_loss: 1.2579 | speed: 0.227 s/batch
# Epoch [    9/   30] | d_loss: 0.9599 | g_loss: 1.4925 | speed: 0.228 s/batch
# Epoch [    9/   30] | d_loss: 0.9735 | g_loss: 1.5603 | speed: 0.228 s/batch
# Epoch [    9/   30] | d_loss: 1.0793 | g_loss: 1.6617 | speed: 0.228 s/batch
# Epoch [    9/   30] | d_loss: 1.1975 | g_loss: 1.9542 | speed: 0.228 s/batch
# Epoch 9/30 time: 160.40s
# Epoch [   10/   30] | d_loss: 1.0569 | g_loss: 1.1684 | speed: 0.213 s/batch
# Epoch [   10/   30] | d_loss: 1.1538 | g_loss: 1.1106 | speed: 0.229 s/batch
# Epoch [   10/   30] | d_loss: 1.1114 | g_loss: 1.4582 | speed: 0.231 s/batch
# Epoch [   10/   30] | d_loss: 0.9979 | g_loss: 1.4164 | speed: 0.230 s/batch
# Epoch [   10/   30] | d_loss: 0.9345 | g_loss: 1.5723 | speed: 0.232 s/batch
# Epoch [   10/   30] | d_loss: 1.0245 | g_loss: 0.9317 | speed: 0.234 s/batch
# Epoch [   10/   30] | d_loss: 0.9680 | g_loss: 1.5315 | speed: 0.235 s/batch
# Epoch [   10/   30] | d_loss: 1.0989 | g_loss: 1.4371 | speed: 0.234 s/batch
# Epoch [   10/   30] | d_loss: 1.1328 | g_loss: 1.6430 | speed: 0.235 s/batch
# Epoch [   10/   30] | d_loss: 0.9477 | g_loss: 1.2541 | speed: 0.236 s/batch
# Epoch [   10/   30] | d_loss: 1.4434 | g_loss: 0.5447 | speed: 0.235 s/batch
# Epoch [   10/   30] | d_loss: 1.1182 | g_loss: 0.8807 | speed: 0.235 s/batch
# Epoch [   10/   30] | d_loss: 0.9656 | g_loss: 1.4001 | speed: 0.239 s/batch
# Epoch [   10/   30] | d_loss: 1.0006 | g_loss: 1.4973 | speed: 0.243 s/batch
# Epoch [   10/   30] | d_loss: 1.1091 | g_loss: 0.8041 | speed: 0.247 s/batch
# Epoch 10/30 time: 173.46s
# Epoch [   11/   30] | d_loss: 1.0565 | g_loss: 1.2946 | speed: 0.294 s/batch
# Epoch [   11/   30] | d_loss: 0.9877 | g_loss: 1.2545 | speed: 0.292 s/batch
# Epoch [   11/   30] | d_loss: 1.0449 | g_loss: 1.3163 | speed: 0.292 s/batch
# Epoch [   11/   30] | d_loss: 1.0060 | g_loss: 1.0953 | speed: 0.292 s/batch
# Epoch [   11/   30] | d_loss: 0.9428 | g_loss: 1.3979 | speed: 0.293 s/batch
# Epoch [   11/   30] | d_loss: 0.9184 | g_loss: 1.3531 | speed: 0.292 s/batch
# Epoch [   11/   30] | d_loss: 0.9284 | g_loss: 1.3474 | speed: 0.293 s/batch
# Epoch [   11/   30] | d_loss: 0.9632 | g_loss: 1.1942 | speed: 0.293 s/batch
# Epoch [   11/   30] | d_loss: 1.0973 | g_loss: 1.2190 | speed: 0.293 s/batch
# Epoch [   11/   30] | d_loss: 1.0693 | g_loss: 1.0143 | speed: 0.293 s/batch
# Epoch [   11/   30] | d_loss: 1.0024 | g_loss: 1.1924 | speed: 0.293 s/batch
# Epoch [   11/   30] | d_loss: 0.9407 | g_loss: 1.3403 | speed: 0.293 s/batch
# Epoch [   11/   30] | d_loss: 1.0102 | g_loss: 1.0079 | speed: 0.293 s/batch
# Epoch [   11/   30] | d_loss: 0.9803 | g_loss: 1.4009 | speed: 0.293 s/batch
# Epoch [   11/   30] | d_loss: 1.0839 | g_loss: 0.9046 | speed: 0.292 s/batch
# Epoch 11/30 time: 205.48s
# Epoch [   12/   30] | d_loss: 0.9939 | g_loss: 1.1968 | speed: 0.295 s/batch
# Epoch [   12/   30] | d_loss: 1.0299 | g_loss: 1.5054 | speed: 0.294 s/batch
# Epoch [   12/   30] | d_loss: 0.9516 | g_loss: 1.2803 | speed: 0.294 s/batch
# Epoch [   12/   30] | d_loss: 1.0098 | g_loss: 1.2752 | speed: 0.294 s/batch
# Epoch [   12/   30] | d_loss: 0.9830 | g_loss: 1.3028 | speed: 0.293 s/batch
# Epoch [   12/   30] | d_loss: 1.1183 | g_loss: 1.0264 | speed: 0.293 s/batch
# Epoch [   12/   30] | d_loss: 1.1579 | g_loss: 0.9390 | speed: 0.292 s/batch
# Epoch [   12/   30] | d_loss: 0.9835 | g_loss: 1.2508 | speed: 0.292 s/batch
# Epoch [   12/   30] | d_loss: 0.9892 | g_loss: 1.1738 | speed: 0.292 s/batch
# Epoch [   12/   30] | d_loss: 1.1217 | g_loss: 1.5066 | speed: 0.292 s/batch
# Epoch [   12/   30] | d_loss: 1.1020 | g_loss: 1.0114 | speed: 0.292 s/batch
# Epoch [   12/   30] | d_loss: 1.0211 | g_loss: 1.1747 | speed: 0.292 s/batch
# Epoch [   12/   30] | d_loss: 1.1078 | g_loss: 1.1258 | speed: 0.292 s/batch
# Epoch [   12/   30] | d_loss: 0.8845 | g_loss: 1.2213 | speed: 0.292 s/batch
# Epoch [   12/   30] | d_loss: 1.1542 | g_loss: 1.0666 | speed: 0.292 s/batch
# Epoch 12/30 time: 205.41s
# Epoch [   13/   30] | d_loss: 1.1010 | g_loss: 1.2641 | speed: 0.291 s/batch
# Epoch [   13/   30] | d_loss: 1.0437 | g_loss: 0.9329 | speed: 0.289 s/batch
# Epoch [   13/   30] | d_loss: 1.0312 | g_loss: 1.2207 | speed: 0.291 s/batch
# Epoch [   13/   30] | d_loss: 1.0025 | g_loss: 1.2045 | speed: 0.291 s/batch
# Epoch [   13/   30] | d_loss: 1.0032 | g_loss: 1.3504 | speed: 0.291 s/batch
# Epoch [   13/   30] | d_loss: 1.0998 | g_loss: 1.0545 | speed: 0.291 s/batch
# Epoch [   13/   30] | d_loss: 1.1179 | g_loss: 1.2545 | speed: 0.292 s/batch
# Epoch [   13/   30] | d_loss: 0.9239 | g_loss: 1.1610 | speed: 0.292 s/batch
# Epoch [   13/   30] | d_loss: 1.0733 | g_loss: 1.0437 | speed: 0.292 s/batch
# Epoch [   13/   30] | d_loss: 1.1126 | g_loss: 1.0715 | speed: 0.292 s/batch
# Epoch [   13/   30] | d_loss: 1.0395 | g_loss: 1.2952 | speed: 0.293 s/batch
# Epoch [   13/   30] | d_loss: 0.9665 | g_loss: 1.2235 | speed: 0.292 s/batch
# Epoch [   13/   30] | d_loss: 1.0128 | g_loss: 1.0569 | speed: 0.293 s/batch
# Epoch [   13/   30] | d_loss: 1.0728 | g_loss: 1.3290 | speed: 0.293 s/batch
# Epoch [   13/   30] | d_loss: 1.0584 | g_loss: 1.4499 | speed: 0.292 s/batch
# Epoch 13/30 time: 205.58s
# Epoch [   14/   30] | d_loss: 1.0492 | g_loss: 1.0998 | speed: 0.232 s/batch
# Epoch [   14/   30] | d_loss: 1.0467 | g_loss: 0.9836 | speed: 0.292 s/batch
# Epoch [   14/   30] | d_loss: 1.0154 | g_loss: 1.0978 | speed: 0.292 s/batch
# Epoch [   14/   30] | d_loss: 1.0108 | g_loss: 1.6284 | speed: 0.291 s/batch
# Epoch [   14/   30] | d_loss: 1.0294 | g_loss: 1.0838 | speed: 0.292 s/batch
# Epoch [   14/   30] | d_loss: 1.1713 | g_loss: 1.2040 | speed: 0.292 s/batch
# Epoch [   14/   30] | d_loss: 1.0010 | g_loss: 1.2363 | speed: 0.292 s/batch
# Epoch [   14/   30] | d_loss: 1.0574 | g_loss: 1.3140 | speed: 0.292 s/batch
# Epoch [   14/   30] | d_loss: 0.9433 | g_loss: 1.3465 | speed: 0.292 s/batch
# Epoch [   14/   30] | d_loss: 1.1293 | g_loss: 1.1165 | speed: 0.292 s/batch
# Epoch [   14/   30] | d_loss: 1.0881 | g_loss: 1.2758 | speed: 0.292 s/batch
# Epoch [   14/   30] | d_loss: 1.0317 | g_loss: 1.4098 | speed: 0.292 s/batch
# Epoch [   14/   30] | d_loss: 1.0828 | g_loss: 1.1719 | speed: 0.292 s/batch
# Epoch [   14/   30] | d_loss: 0.9620 | g_loss: 1.5011 | speed: 0.292 s/batch
# Epoch [   14/   30] | d_loss: 1.0616 | g_loss: 1.0988 | speed: 0.292 s/batch
# Epoch 14/30 time: 205.38s
# Epoch [   15/   30] | d_loss: 1.1429 | g_loss: 1.2083 | speed: 0.315 s/batch
# Epoch [   15/   30] | d_loss: 0.8001 | g_loss: 1.3622 | speed: 0.295 s/batch
# Epoch [   15/   30] | d_loss: 1.0723 | g_loss: 1.2892 | speed: 0.294 s/batch
# Epoch [   15/   30] | d_loss: 0.9582 | g_loss: 1.0532 | speed: 0.294 s/batch
# Epoch [   15/   30] | d_loss: 1.1515 | g_loss: 1.1412 | speed: 0.293 s/batch
# Epoch [   15/   30] | d_loss: 1.0818 | g_loss: 1.4991 | speed: 0.293 s/batch
# Epoch [   15/   30] | d_loss: 0.9573 | g_loss: 1.5763 | speed: 0.293 s/batch
# Epoch [   15/   30] | d_loss: 0.9925 | g_loss: 1.4056 | speed: 0.293 s/batch
# Epoch [   15/   30] | d_loss: 1.0934 | g_loss: 1.3232 | speed: 0.293 s/batch
# Epoch [   15/   30] | d_loss: 1.0666 | g_loss: 1.0046 | speed: 0.293 s/batch
# Epoch [   15/   30] | d_loss: 0.9402 | g_loss: 1.3964 | speed: 0.293 s/batch
# Epoch [   15/   30] | d_loss: 1.0342 | g_loss: 0.8227 | speed: 0.293 s/batch
# Epoch [   15/   30] | d_loss: 0.9554 | g_loss: 1.0069 | speed: 0.293 s/batch
# Epoch [   15/   30] | d_loss: 0.9646 | g_loss: 1.1300 | speed: 0.293 s/batch
# Epoch [   15/   30] | d_loss: 1.1344 | g_loss: 1.0059 | speed: 0.293 s/batch
# Epoch 15/30 time: 206.10s
# Epoch [   16/   30] | d_loss: 1.0551 | g_loss: 1.0866 | speed: 0.228 s/batch
# Epoch [   16/   30] | d_loss: 0.9506 | g_loss: 0.9803 | speed: 0.292 s/batch
# Epoch [   16/   30] | d_loss: 1.1153 | g_loss: 1.9415 | speed: 0.293 s/batch
# Epoch [   16/   30] | d_loss: 1.3795 | g_loss: 1.4669 | speed: 0.295 s/batch
# Epoch [   16/   30] | d_loss: 0.9794 | g_loss: 1.4591 | speed: 0.295 s/batch
# Epoch [   16/   30] | d_loss: 1.1060 | g_loss: 1.1846 | speed: 0.295 s/batch
# Epoch [   16/   30] | d_loss: 1.0377 | g_loss: 0.9956 | speed: 0.295 s/batch
# Epoch [   16/   30] | d_loss: 1.0176 | g_loss: 1.2802 | speed: 0.294 s/batch
# Epoch [   16/   30] | d_loss: 1.0066 | g_loss: 1.3202 | speed: 0.294 s/batch
# Epoch [   16/   30] | d_loss: 1.0007 | g_loss: 1.1333 | speed: 0.294 s/batch
# Epoch [   16/   30] | d_loss: 1.0138 | g_loss: 1.1700 | speed: 0.294 s/batch
# Epoch [   16/   30] | d_loss: 1.0206 | g_loss: 1.1135 | speed: 0.294 s/batch
# Epoch [   16/   30] | d_loss: 1.0870 | g_loss: 1.9692 | speed: 0.294 s/batch
# Epoch [   16/   30] | d_loss: 1.0856 | g_loss: 1.1370 | speed: 0.294 s/batch
# Epoch [   16/   30] | d_loss: 1.1486 | g_loss: 1.1396 | speed: 0.294 s/batch
# Epoch 16/30 time: 206.82s
# Epoch [   17/   30] | d_loss: 1.0425 | g_loss: 1.7861 | speed: 0.292 s/batch
# Epoch [   17/   30] | d_loss: 1.2010 | g_loss: 1.0099 | speed: 0.294 s/batch
# Epoch [   17/   30] | d_loss: 1.1484 | g_loss: 1.5983 | speed: 0.294 s/batch
# Epoch [   17/   30] | d_loss: 0.9893 | g_loss: 1.1530 | speed: 0.294 s/batch
# Epoch [   17/   30] | d_loss: 1.1176 | g_loss: 1.2265 | speed: 0.294 s/batch
# Epoch [   17/   30] | d_loss: 0.9983 | g_loss: 1.0732 | speed: 0.293 s/batch
# Epoch [   17/   30] | d_loss: 1.0285 | g_loss: 1.2950 | speed: 0.294 s/batch
# Epoch [   17/   30] | d_loss: 1.0777 | g_loss: 1.3369 | speed: 0.294 s/batch
# Epoch [   17/   30] | d_loss: 1.1649 | g_loss: 1.4295 | speed: 0.294 s/batch
# Epoch [   17/   30] | d_loss: 1.0577 | g_loss: 1.2485 | speed: 0.293 s/batch
# Epoch [   17/   30] | d_loss: 1.0978 | g_loss: 1.1776 | speed: 0.293 s/batch
# Epoch [   17/   30] | d_loss: 1.2345 | g_loss: 0.8780 | speed: 0.294 s/batch
# Epoch [   17/   30] | d_loss: 0.9136 | g_loss: 1.1765 | speed: 0.294 s/batch
# Epoch [   17/   30] | d_loss: 1.0982 | g_loss: 1.1646 | speed: 0.294 s/batch
# Epoch [   17/   30] | d_loss: 1.2393 | g_loss: 1.6305 | speed: 0.294 s/batch
# Epoch 17/30 time: 206.65s
# Epoch [   18/   30] | d_loss: 1.0478 | g_loss: 1.3934 | speed: 0.294 s/batch
# Epoch [   18/   30] | d_loss: 1.1186 | g_loss: 0.9661 | speed: 0.291 s/batch
# Epoch [   18/   30] | d_loss: 0.9996 | g_loss: 1.3372 | speed: 0.293 s/batch
# Epoch [   18/   30] | d_loss: 0.9626 | g_loss: 1.1896 | speed: 0.292 s/batch
# Epoch [   18/   30] | d_loss: 1.0532 | g_loss: 0.8901 | speed: 0.293 s/batch
# Epoch [   18/   30] | d_loss: 0.9676 | g_loss: 1.3749 | speed: 0.294 s/batch
# Epoch [   18/   30] | d_loss: 1.0297 | g_loss: 1.2601 | speed: 0.294 s/batch
# Epoch [   18/   30] | d_loss: 0.9918 | g_loss: 1.2136 | speed: 0.294 s/batch
# Epoch [   18/   30] | d_loss: 1.0108 | g_loss: 1.5875 | speed: 0.294 s/batch
# Epoch [   18/   30] | d_loss: 1.0504 | g_loss: 1.2649 | speed: 0.294 s/batch
# Epoch [   18/   30] | d_loss: 1.1337 | g_loss: 0.8604 | speed: 0.294 s/batch
# Epoch [   18/   30] | d_loss: 1.0683 | g_loss: 0.9509 | speed: 0.294 s/batch
# Epoch [   18/   30] | d_loss: 1.0906 | g_loss: 1.2229 | speed: 0.294 s/batch
# Epoch [   18/   30] | d_loss: 1.1995 | g_loss: 1.1598 | speed: 0.294 s/batch
# Epoch [   18/   30] | d_loss: 1.0982 | g_loss: 1.3653 | speed: 0.294 s/batch
# Epoch 18/30 time: 206.61s
# Epoch [   19/   30] | d_loss: 1.1377 | g_loss: 1.5601 | speed: 0.294 s/batch
# Epoch [   19/   30] | d_loss: 0.9607 | g_loss: 1.2227 | speed: 0.297 s/batch
# Epoch [   19/   30] | d_loss: 0.9136 | g_loss: 1.3544 | speed: 0.294 s/batch
# Epoch [   19/   30] | d_loss: 1.0454 | g_loss: 1.2782 | speed: 0.294 s/batch
# Epoch [   19/   30] | d_loss: 1.0787 | g_loss: 1.2979 | speed: 0.294 s/batch
# Epoch [   19/   30] | d_loss: 1.0986 | g_loss: 1.1084 | speed: 0.294 s/batch
# Epoch [   19/   30] | d_loss: 1.1141 | g_loss: 1.2372 | speed: 0.294 s/batch
# Epoch [   19/   30] | d_loss: 0.9622 | g_loss: 1.1442 | speed: 0.294 s/batch
# Epoch [   19/   30] | d_loss: 1.1635 | g_loss: 0.8867 | speed: 0.294 s/batch
# Epoch [   19/   30] | d_loss: 1.1061 | g_loss: 1.4667 | speed: 0.294 s/batch
# Epoch [   19/   30] | d_loss: 1.1471 | g_loss: 1.4702 | speed: 0.294 s/batch
# Epoch [   19/   30] | d_loss: 0.9845 | g_loss: 1.4078 | speed: 0.295 s/batch
# Epoch [   19/   30] | d_loss: 0.9440 | g_loss: 1.4557 | speed: 0.295 s/batch
# Epoch [   19/   30] | d_loss: 1.0391 | g_loss: 1.2701 | speed: 0.295 s/batch
# Epoch [   19/   30] | d_loss: 0.9931 | g_loss: 1.4028 | speed: 0.295 s/batch
# Epoch 19/30 time: 207.31s
# Epoch [   20/   30] | d_loss: 0.9585 | g_loss: 1.2919 | speed: 0.293 s/batch
# Epoch [   20/   30] | d_loss: 1.1359 | g_loss: 1.3296 | speed: 0.289 s/batch
# Epoch [   20/   30] | d_loss: 1.0922 | g_loss: 1.1953 | speed: 0.293 s/batch
# Epoch [   20/   30] | d_loss: 0.9913 | g_loss: 1.4224 | speed: 0.292 s/batch
# Epoch [   20/   30] | d_loss: 1.0134 | g_loss: 1.0370 | speed: 0.293 s/batch
# Epoch [   20/   30] | d_loss: 1.0247 | g_loss: 1.5831 | speed: 0.294 s/batch
# Epoch [   20/   30] | d_loss: 1.0001 | g_loss: 1.3246 | speed: 0.294 s/batch
# Epoch [   20/   30] | d_loss: 1.0623 | g_loss: 1.3898 | speed: 0.295 s/batch
# Epoch [   20/   30] | d_loss: 0.9272 | g_loss: 1.3896 | speed: 0.294 s/batch
# Epoch [   20/   30] | d_loss: 1.0251 | g_loss: 1.4532 | speed: 0.294 s/batch
# Epoch [   20/   30] | d_loss: 0.9697 | g_loss: 1.1240 | speed: 0.295 s/batch
# Epoch [   20/   30] | d_loss: 1.0662 | g_loss: 1.3527 | speed: 0.295 s/batch
# Epoch [   20/   30] | d_loss: 1.2643 | g_loss: 0.8927 | speed: 0.295 s/batch
# Epoch [   20/   30] | d_loss: 1.1497 | g_loss: 0.7644 | speed: 0.295 s/batch
# Epoch [   20/   30] | d_loss: 1.0588 | g_loss: 1.1198 | speed: 0.295 s/batch
# Epoch 20/30 time: 207.21s
# Epoch [   21/   30] | d_loss: 1.0278 | g_loss: 1.1283 | speed: 0.299 s/batch
# Epoch [   21/   30] | d_loss: 1.0647 | g_loss: 1.3120 | speed: 0.288 s/batch
# Epoch [   21/   30] | d_loss: 0.9475 | g_loss: 1.2665 | speed: 0.290 s/batch
# Epoch [   21/   30] | d_loss: 1.1593 | g_loss: 1.0588 | speed: 0.292 s/batch
# Epoch [   21/   30] | d_loss: 0.9499 | g_loss: 1.3493 | speed: 0.293 s/batch
# Epoch [   21/   30] | d_loss: 1.0482 | g_loss: 1.0826 | speed: 0.294 s/batch
# Epoch [   21/   30] | d_loss: 1.0972 | g_loss: 1.1519 | speed: 0.294 s/batch
# Epoch [   21/   30] | d_loss: 0.9763 | g_loss: 1.1935 | speed: 0.294 s/batch
# Epoch [   21/   30] | d_loss: 0.8787 | g_loss: 1.3695 | speed: 0.294 s/batch
# Epoch [   21/   30] | d_loss: 1.0745 | g_loss: 1.0514 | speed: 0.294 s/batch
# Epoch [   21/   30] | d_loss: 0.9512 | g_loss: 1.1921 | speed: 0.295 s/batch
# Epoch [   21/   30] | d_loss: 1.1641 | g_loss: 1.2523 | speed: 0.295 s/batch
# Epoch [   21/   30] | d_loss: 1.0189 | g_loss: 1.0927 | speed: 0.295 s/batch
# Epoch [   21/   30] | d_loss: 1.1000 | g_loss: 1.2446 | speed: 0.295 s/batch
# Epoch [   21/   30] | d_loss: 1.0675 | g_loss: 1.1147 | speed: 0.295 s/batch
# Epoch 21/30 time: 207.45s
# Epoch [   22/   30] | d_loss: 1.2602 | g_loss: 1.0854 | speed: 0.315 s/batch
# Epoch [   22/   30] | d_loss: 1.1386 | g_loss: 1.0553 | speed: 0.296 s/batch
# Epoch [   22/   30] | d_loss: 0.8991 | g_loss: 1.0763 | speed: 0.296 s/batch
# Epoch [   22/   30] | d_loss: 1.0073 | g_loss: 1.2353 | speed: 0.296 s/batch
# Epoch [   22/   30] | d_loss: 0.9355 | g_loss: 1.1828 | speed: 0.295 s/batch
# Epoch [   22/   30] | d_loss: 1.0214 | g_loss: 1.1629 | speed: 0.295 s/batch
# Epoch [   22/   30] | d_loss: 0.9657 | g_loss: 1.1468 | speed: 0.295 s/batch
# Epoch [   22/   30] | d_loss: 0.9990 | g_loss: 1.1262 | speed: 0.295 s/batch
# Epoch [   22/   30] | d_loss: 1.0428 | g_loss: 0.9934 | speed: 0.296 s/batch
# Epoch [   22/   30] | d_loss: 0.9374 | g_loss: 1.2639 | speed: 0.296 s/batch
# Epoch [   22/   30] | d_loss: 0.9646 | g_loss: 1.3804 | speed: 0.296 s/batch
# Epoch [   22/   30] | d_loss: 1.2101 | g_loss: 1.0706 | speed: 0.296 s/batch
# Epoch [   22/   30] | d_loss: 0.8808 | g_loss: 1.2228 | speed: 0.296 s/batch
# Epoch [   22/   30] | d_loss: 1.1166 | g_loss: 1.2270 | speed: 0.296 s/batch
# Epoch [   22/   30] | d_loss: 0.9081 | g_loss: 1.3740 | speed: 0.296 s/batch
# Epoch 22/30 time: 207.87s
# Epoch [   23/   30] | d_loss: 1.1515 | g_loss: 0.9288 | speed: 0.291 s/batch
# Epoch [   23/   30] | d_loss: 0.9579 | g_loss: 1.0975 | speed: 0.299 s/batch
# Epoch [   23/   30] | d_loss: 0.9889 | g_loss: 1.0856 | speed: 0.298 s/batch
# Epoch [   23/   30] | d_loss: 1.0834 | g_loss: 1.0975 | speed: 0.297 s/batch
# Epoch [   23/   30] | d_loss: 1.0819 | g_loss: 1.1748 | speed: 0.296 s/batch
# Epoch [   23/   30] | d_loss: 1.0246 | g_loss: 1.1181 | speed: 0.295 s/batch
# Epoch [   23/   30] | d_loss: 1.0405 | g_loss: 1.2886 | speed: 0.296 s/batch
# Epoch [   23/   30] | d_loss: 1.2203 | g_loss: 1.2497 | speed: 0.295 s/batch
# Epoch [   23/   30] | d_loss: 0.9779 | g_loss: 1.1529 | speed: 0.296 s/batch
# Epoch [   23/   30] | d_loss: 1.0121 | g_loss: 1.3021 | speed: 0.296 s/batch
# Epoch [   23/   30] | d_loss: 1.0577 | g_loss: 1.2710 | speed: 0.296 s/batch
# Epoch [   23/   30] | d_loss: 1.1961 | g_loss: 1.0563 | speed: 0.296 s/batch
# Epoch [   23/   30] | d_loss: 1.1215 | g_loss: 1.0815 | speed: 0.296 s/batch
# Epoch [   23/   30] | d_loss: 1.1635 | g_loss: 0.9131 | speed: 0.295 s/batch
# Epoch [   23/   30] | d_loss: 1.1428 | g_loss: 1.1167 | speed: 0.296 s/batch
# Epoch 23/30 time: 207.75s
# Epoch [   24/   30] | d_loss: 1.1148 | g_loss: 1.1264 | speed: 0.263 s/batch
# Epoch [   24/   30] | d_loss: 1.0184 | g_loss: 1.2390 | speed: 0.289 s/batch
# Epoch [   24/   30] | d_loss: 0.9307 | g_loss: 1.2932 | speed: 0.290 s/batch
# Epoch [   24/   30] | d_loss: 1.0042 | g_loss: 1.2466 | speed: 0.292 s/batch
# Epoch [   24/   30] | d_loss: 1.0238 | g_loss: 1.0411 | speed: 0.293 s/batch
# Epoch [   24/   30] | d_loss: 1.2168 | g_loss: 1.0389 | speed: 0.293 s/batch
# Epoch [   24/   30] | d_loss: 1.0210 | g_loss: 1.2308 | speed: 0.294 s/batch
# Epoch [   24/   30] | d_loss: 1.0294 | g_loss: 1.3502 | speed: 0.294 s/batch
# Epoch [   24/   30] | d_loss: 0.9890 | g_loss: 1.0998 | speed: 0.294 s/batch
# Epoch [   24/   30] | d_loss: 1.2771 | g_loss: 1.3178 | speed: 0.294 s/batch
# Epoch [   24/   30] | d_loss: 1.0341 | g_loss: 1.1750 | speed: 0.294 s/batch
# Epoch [   24/   30] | d_loss: 1.3228 | g_loss: 1.0225 | speed: 0.294 s/batch
# Epoch [   24/   30] | d_loss: 0.9788 | g_loss: 0.8280 | speed: 0.294 s/batch
# Epoch [   24/   30] | d_loss: 1.0528 | g_loss: 1.0997 | speed: 0.294 s/batch
# Epoch [   24/   30] | d_loss: 1.0815 | g_loss: 1.3169 | speed: 0.294 s/batch
# Epoch 24/30 time: 206.77s
# Epoch [   25/   30] | d_loss: 1.0437 | g_loss: 0.9944 | speed: 0.225 s/batch
# Epoch [   25/   30] | d_loss: 1.0454 | g_loss: 1.2577 | speed: 0.292 s/batch
# Epoch [   25/   30] | d_loss: 1.0995 | g_loss: 1.2278 | speed: 0.293 s/batch
# Epoch [   25/   30] | d_loss: 1.1787 | g_loss: 1.1681 | speed: 0.294 s/batch
# Epoch [   25/   30] | d_loss: 1.1737 | g_loss: 0.9338 | speed: 0.295 s/batch
# Epoch [   25/   30] | d_loss: 1.0741 | g_loss: 1.2751 | speed: 0.295 s/batch
# Epoch [   25/   30] | d_loss: 1.1530 | g_loss: 1.1132 | speed: 0.295 s/batch
# Epoch [   25/   30] | d_loss: 1.0371 | g_loss: 1.2361 | speed: 0.296 s/batch
# Epoch [   25/   30] | d_loss: 1.0019 | g_loss: 1.0595 | speed: 0.295 s/batch
# Epoch [   25/   30] | d_loss: 1.0916 | g_loss: 1.1059 | speed: 0.295 s/batch
# Epoch [   25/   30] | d_loss: 1.1766 | g_loss: 0.9335 | speed: 0.295 s/batch
# Epoch [   25/   30] | d_loss: 1.1220 | g_loss: 1.1796 | speed: 0.295 s/batch
# Epoch [   25/   30] | d_loss: 0.9396 | g_loss: 1.2324 | speed: 0.296 s/batch
# Epoch [   25/   30] | d_loss: 1.0783 | g_loss: 1.1390 | speed: 0.296 s/batch
# Epoch [   25/   30] | d_loss: 1.1059 | g_loss: 1.5073 | speed: 0.295 s/batch
# Epoch 25/30 time: 207.62s
# Epoch [   26/   30] | d_loss: 0.9957 | g_loss: 1.0512 | speed: 0.270 s/batch
# Epoch [   26/   30] | d_loss: 1.0656 | g_loss: 1.1122 | speed: 0.293 s/batch
# Epoch [   26/   30] | d_loss: 1.0706 | g_loss: 1.1093 | speed: 0.296 s/batch
# Epoch [   26/   30] | d_loss: 0.9598 | g_loss: 1.2306 | speed: 0.295 s/batch
# Epoch [   26/   30] | d_loss: 1.0282 | g_loss: 1.0827 | speed: 0.295 s/batch
# Epoch [   26/   30] | d_loss: 1.0419 | g_loss: 1.2397 | speed: 0.295 s/batch
# Epoch [   26/   30] | d_loss: 0.9819 | g_loss: 1.2755 | speed: 0.296 s/batch
# Epoch [   26/   30] | d_loss: 1.0591 | g_loss: 1.1334 | speed: 0.296 s/batch
# Epoch [   26/   30] | d_loss: 1.0446 | g_loss: 1.0375 | speed: 0.296 s/batch
# Epoch [   26/   30] | d_loss: 1.0367 | g_loss: 1.1894 | speed: 0.296 s/batch
# Epoch [   26/   30] | d_loss: 1.0861 | g_loss: 1.3074 | speed: 0.295 s/batch
# Epoch [   26/   30] | d_loss: 1.0560 | g_loss: 1.2974 | speed: 0.295 s/batch
# Epoch [   26/   30] | d_loss: 0.9189 | g_loss: 0.9122 | speed: 0.295 s/batch
# Epoch [   26/   30] | d_loss: 1.1269 | g_loss: 1.0921 | speed: 0.295 s/batch
# Epoch [   26/   30] | d_loss: 0.9384 | g_loss: 1.1062 | speed: 0.295 s/batch
# Epoch 26/30 time: 207.02s
# Epoch [   27/   30] | d_loss: 1.0826 | g_loss: 0.9723 | speed: 0.286 s/batch
# Epoch [   27/   30] | d_loss: 1.0963 | g_loss: 1.1296 | speed: 0.297 s/batch
# Epoch [   27/   30] | d_loss: 0.9601 | g_loss: 1.1870 | speed: 0.296 s/batch
# Epoch [   27/   30] | d_loss: 0.9637 | g_loss: 1.2722 | speed: 0.297 s/batch
# Epoch [   27/   30] | d_loss: 1.0958 | g_loss: 1.2633 | speed: 0.296 s/batch
# Epoch [   27/   30] | d_loss: 0.9764 | g_loss: 1.1163 | speed: 0.296 s/batch
# Epoch [   27/   30] | d_loss: 1.0848 | g_loss: 1.1045 | speed: 0.297 s/batch
# Epoch [   27/   30] | d_loss: 1.0813 | g_loss: 1.1764 | speed: 0.296 s/batch
# Epoch [   27/   30] | d_loss: 1.0050 | g_loss: 1.3854 | speed: 0.296 s/batch
# Epoch [   27/   30] | d_loss: 1.1012 | g_loss: 0.8739 | speed: 0.297 s/batch
# Epoch [   27/   30] | d_loss: 0.9817 | g_loss: 1.1465 | speed: 0.297 s/batch
# Epoch [   27/   30] | d_loss: 1.0014 | g_loss: 1.0710 | speed: 0.297 s/batch
# Epoch [   27/   30] | d_loss: 0.9761 | g_loss: 0.9641 | speed: 0.297 s/batch
# Epoch [   27/   30] | d_loss: 1.0680 | g_loss: 0.9917 | speed: 0.297 s/batch
# Epoch [   27/   30] | d_loss: 1.1299 | g_loss: 1.1168 | speed: 0.297 s/batch
# Epoch 27/30 time: 208.46s
# Epoch [   28/   30] | d_loss: 1.0145 | g_loss: 1.3077 | speed: 0.297 s/batch
# Epoch [   28/   30] | d_loss: 1.0523 | g_loss: 1.2189 | speed: 0.295 s/batch
# Epoch [   28/   30] | d_loss: 1.0632 | g_loss: 1.3673 | speed: 0.296 s/batch
# Epoch [   28/   30] | d_loss: 1.0783 | g_loss: 1.1354 | speed: 0.295 s/batch
# Epoch [   28/   30] | d_loss: 1.0803 | g_loss: 1.2010 | speed: 0.295 s/batch
# Epoch [   28/   30] | d_loss: 1.0928 | g_loss: 1.1126 | speed: 0.295 s/batch
# Epoch [   28/   30] | d_loss: 0.9268 | g_loss: 1.1903 | speed: 0.295 s/batch
# Epoch [   28/   30] | d_loss: 1.1445 | g_loss: 1.3304 | speed: 0.296 s/batch
# Epoch [   28/   30] | d_loss: 1.0754 | g_loss: 1.1834 | speed: 0.296 s/batch
# Epoch [   28/   30] | d_loss: 1.1556 | g_loss: 1.2760 | speed: 0.296 s/batch
# Epoch [   28/   30] | d_loss: 1.1924 | g_loss: 1.0142 | speed: 0.296 s/batch
# Epoch [   28/   30] | d_loss: 1.0691 | g_loss: 1.0932 | speed: 0.296 s/batch
# Epoch [   28/   30] | d_loss: 0.9675 | g_loss: 1.1964 | speed: 0.296 s/batch
# Epoch [   28/   30] | d_loss: 1.1011 | g_loss: 1.3405 | speed: 0.296 s/batch
# Epoch [   28/   30] | d_loss: 1.1179 | g_loss: 1.0414 | speed: 0.296 s/batch
# Epoch 28/30 time: 208.02s
# Epoch [   29/   30] | d_loss: 1.0332 | g_loss: 1.2066 | speed: 0.292 s/batch
# Epoch [   29/   30] | d_loss: 1.1214 | g_loss: 0.9008 | speed: 0.296 s/batch
# Epoch [   29/   30] | d_loss: 1.0042 | g_loss: 1.3416 | speed: 0.298 s/batch
# Epoch [   29/   30] | d_loss: 1.0758 | g_loss: 1.1092 | speed: 0.297 s/batch
# Epoch [   29/   30] | d_loss: 1.0049 | g_loss: 1.1640 | speed: 0.296 s/batch
# Epoch [   29/   30] | d_loss: 0.9301 | g_loss: 1.0324 | speed: 0.296 s/batch
# Epoch [   29/   30] | d_loss: 0.9477 | g_loss: 1.1461 | speed: 0.296 s/batch
# Epoch [   29/   30] | d_loss: 1.0375 | g_loss: 1.2152 | speed: 0.297 s/batch
# Epoch [   29/   30] | d_loss: 1.0044 | g_loss: 1.0792 | speed: 0.296 s/batch
# Epoch [   29/   30] | d_loss: 0.9683 | g_loss: 1.0860 | speed: 0.297 s/batch
# Epoch [   29/   30] | d_loss: 1.1252 | g_loss: 0.9869 | speed: 0.296 s/batch
# Epoch [   29/   30] | d_loss: 1.2435 | g_loss: 1.1856 | speed: 0.296 s/batch
# Epoch [   29/   30] | d_loss: 1.0772 | g_loss: 1.1033 | speed: 0.296 s/batch
# Epoch [   29/   30] | d_loss: 1.0372 | g_loss: 1.2804 | speed: 0.296 s/batch
# Epoch [   29/   30] | d_loss: 1.0707 | g_loss: 1.0161 | speed: 0.296 s/batch
# Epoch 29/30 time: 208.11s
# Epoch [   30/   30] | d_loss: 0.9594 | g_loss: 1.2651 | speed: 0.306 s/batch
# Epoch [   30/   30] | d_loss: 0.9315 | g_loss: 1.1590 | speed: 0.299 s/batch
# Epoch [   30/   30] | d_loss: 0.9958 | g_loss: 1.3841 | speed: 0.301 s/batch
# Epoch [   30/   30] | d_loss: 1.0591 | g_loss: 1.0861 | speed: 0.302 s/batch
# Epoch [   30/   30] | d_loss: 1.0420 | g_loss: 1.1230 | speed: 0.302 s/batch
# Epoch [   30/   30] | d_loss: 1.0269 | g_loss: 1.1668 | speed: 0.301 s/batch
# Epoch [   30/   30] | d_loss: 1.1263 | g_loss: 1.2797 | speed: 0.301 s/batch
# Epoch [   30/   30] | d_loss: 1.1744 | g_loss: 1.2955 | speed: 0.301 s/batch
# Epoch [   30/   30] | d_loss: 0.9233 | g_loss: 1.2587 | speed: 0.301 s/batch
# Epoch [   30/   30] | d_loss: 0.9783 | g_loss: 1.1470 | speed: 0.301 s/batch
# Epoch [   30/   30] | d_loss: 1.0376 | g_loss: 1.2235 | speed: 0.301 s/batch
# Epoch [   30/   30] | d_loss: 1.0325 | g_loss: 1.4685 | speed: 0.300 s/batch
# Epoch [   30/   30] | d_loss: 1.0786 | g_loss: 1.2138 | speed: 0.300 s/batch
# Epoch [   30/   30] | d_loss: 0.9631 | g_loss: 1.3620 | speed: 0.300 s/batch
# Epoch [   30/   30] | d_loss: 1.0468 | g_loss: 0.8098 | speed: 0.300 s/batch
# Epoch 30/30 time: 210.65s

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:**
# * The generated images are also biased, similar to the training data. A possible way to mitigate bias is to have multi-classes data and to do proper weighting.
# * Resnet style models are built for both discriminators and generators, which have around 4 and 10 layers respectively. This well-known design comes with proven good capacity to extract features effectively. Meanwhile, the networks have large kernel size and numerous filters to avoid zero discriminator loss.
# * Since discriminator and generator are being trained at the same time, the learning rate must be carefully tuned, and a small value is chosen after some trials. The main purpose is also to avoid zero discriminate loss, which may ruin the training completely.
# * From the experiments, it can be seen that the discriminator could more easily distinguish the real and fake images, especially at the very beginning where the fake images don't make sense at all. The generator, on the contrary, upsamples an image from a short randomly-initialized vector, and needs more efforts to learn how to generate a fake image. Theses are the reasons why a deeper architecture is adopted for generator.
# * For the `real_loss` and `fake_loss`, some noise is added to soften the 0/1 labels to avoid zero discriminator loss.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
